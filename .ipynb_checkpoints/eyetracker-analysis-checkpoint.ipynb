# %%
import matplotlib.pyplot as plt #実際にプロットする
import numpy as np #データの整理
import pandas as pd #データフレームのライブラリ
import h5py #HDF5のライブラリ
import io

# %%
def PrintAllObjects(name):
    print(name)

dat = []

with h5py.File("data/949259_test2_2025-05-12_18h55.12.918.hdf5",'r') as f:
    data = f["data_collection/events/eyetracker/BinocularEyeSampleEvent"][()]
    dat = data

# %%
values = []
keys = ["device_time","logged_time","time"],
          x["left_gaze_x"],x["left_gaze_y"],x["left_gaze_z"],
          x["right_gaze_x"],x["right_gaze_y"],x["left_gaze_z"],
          x["left_pupil_measure1"], x["right_pupil_measure1"]
for x in dat:
    print(x["device_time"],x["logged_time"],x["time"],
          x["left_gaze_x"],x["left_gaze_y"],x["left_gaze_z"],
          x["right_gaze_x"],x["right_gaze_y"],x["left_gaze_z"],
          x["left_pupil_measure1"], x["right_pupil_measure1"])
# Out:
# 5125066390.0 4.066683599958196 4.053028599941172 nan nan 0.0 nan nan 0.0 nan nan
# 5125098227.0 4.092400799971074 4.084924799972214 nan nan 0.0 nan nan 0.0 nan nan
# 5125114870.0 4.110740799922496 4.1015797998989 0.08501795 0.15620562 0.0 0.054544345 0.12825611 0.0 3.2131042 3.2852173
# 5125131460.0 4.1272709999466315 4.118146999971941 0.088614784 0.11910623 0.0 0.10648971 0.0758324 0.0 3.061615 3.0568848
# 5125148353.0 4.143951199948788 4.135047199903056 0.013654073 0.012168795 0.0 0.050572608 -0.01745671 0.0 2.7338104 2.791504
# 5125164740.0 4.161059799953364 4.151409799931571 0.002635638 0.021373183 0.0 0.04150624 -0.00809896 0.0 2.748932 2.8303986
# 5125181278.0 4.1772745999041945 4.167877599946223 0.009004275 0.02923897 0.0 0.037945643 -0.004853368 0.0 2.7426758 2.824707
# 5125198273.0 4.193998800008558 4.1848138000350446 0.011781375 0.03545782 0.0 0.042339962 -0.0016684532 0.0 2.7148895 2.8137817
# ...
